# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
yeld_apples = [0.895, 0.91, 0.919, 0.926, 0.929, 0.931] 
yeld_apples
# Out:
# [0.895, 0.91, 0.919, 0.926, 0.929, 0.931]

# %% [markdown]
# ##Linear Plot

# %%
plt.plot(yeld_apples); #to not show the memory location of the graph

# %% [markdown]
# ###Adjusting the graph on the x-axis

# %%
year=[2010, 2011, 2012, 2013, 2014, 2015]
year
# Out:
# [2010, 2011, 2012, 2013, 2014, 2015]

# %%
plt.plot(year, yeld_apples);

# %% [markdown]
# ###Axis label

# %%
plt.plot(year, yeld_apples)
plt.xlabel('Year')
plt.ylabel('Yeld(Tons per hectare)'); # The ; has to come at the end of the cell D:

# %% [markdown]
# ##Ploting multiple lines

# %%
years = range(2000,2012)
apples = [0.895, 0.91, 0.919, 0.926, 0.929, 0.931, 0.934, 0.936, 0.937, 0.9375, 0.9372, 0.939]
oranges = [0.962, 0.941, 0.930, 0.923, 0.918, 0.908, 0.907, 0.904, 0.901, 0.898, 0.9, 0.896]
apples,oranges
# Out:
# ([0.895,
#   0.91,
#   0.919,
#   0.926,
#   0.929,
#   0.931,
#   0.934,
#   0.936,
#   0.937,
#   0.9375,
#   0.9372,
#   0.939],
#  [0.962,
#   0.941,
#   0.93,
#   0.923,
#   0.918,
#   0.908,
#   0.907,
#   0.904,
#   0.901,
#   0.898,
#   0.9,
#   0.896])

# %%
plt.plot(years, apples)
plt.plot(years, oranges)
plt.xlabel('Year')
plt.ylabel('Yeld (ton per hectare)');

# %% [markdown]
# ##Chart title and legend

# %%
plt.plot(years, apples)
plt.plot(years, oranges)

plt.xlabel('Years')
plt.ylabel('Yeld (ton per hectare)')

plt.title("Crop yelds in Kento")
plt.legend(['Apples', 'Oranges']); #Needs to be in order

# %% [markdown]
# ##Line markers
#
# * `color` or `c` : Color of the line
# * `linestyle` or `ls` : Solid or dashed line
# * `linewidth` or `lw`: The width of the line
# * `markersize` or `ms` : Size of the marker
# * `markeredgecolor` or `mec` : Edge colors of the marker
# * `markeredgewidth` or `mew` : Edge width of the marker
# * `markerfacecolor` or `mfc` : The color that will fill the marker
# * `alpha` : Opacy of the plot

# %%
#Exemple:
plt.plot(years, apples, marker='s', )
plt.plot(years, oranges, marker='o', c='r')

plt.xlabel('Years')
plt.ylabel('Yeld (tons per hectare)')

plt.title("Yelds of Kento")
plt.legend(['Apples', 'Oranges']);

# %% [markdown]
# The `fmt` argument provides a shorthand for specifying the marker shape, line style, and line color. It can be provided as the third argument to `plt.plot.`
#
# `fmt='[marker][line][color]'`

# %%
#Example of fmt:
plt.plot(years, apples, 's-b' )
plt.plot(years, oranges, 'o--r')

plt.xlabel('Years')
plt.ylabel('Yeld (tons per hectare)')

plt.title("Yelds of Kento")
plt.legend(['Apples', 'Oranges']);

# %% [markdown]
# ##Changing the figure size
#
# `pl.figure(figsize=())`

# %%
plt.figure(figsize=(12,6)) # -> ^

plt.plot(years, apples);

# %% [markdown]
# ##Using seaborn
# An easy way to make your charts look beautiful is to use some default styles from the Seaborn library. These can be applied globally using the sns.set_style function. You can see a full list of predefined styles here: https://seaborn.pydata.org/generated/seaborn.set_style.html .

# %%
sns.set_style("whitegrid")

plt.figure(figsize=(12,6))

plt.plot(years, apples)
plt.plot(years, oranges)

plt.title('Yelds of Kento');

# %%
sns.set_style("darkgrid")

plt.figure(figsize=(12,6))

plt.plot(years, apples)
plt.plot(years, oranges)

plt.title('Yelds of Kento');

# %% [markdown]
# #Scatter plot

# %%
#Loading a data frame from sns
flower_df = sns.load_dataset('iris')
flower_df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
flower_df.species.unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
#Relationship between sepal length and sepal width:
plt.figure(figsize=(12,6))
plt.plot(flower_df.sepal_length, flower_df.sepal_width);

# %%
#Using scatter plot
plt.figure(figsize=(12,6))
sns.scatterplot(x=flower_df.sepal_length, y=flower_df.sepal_width);

# %% [markdown]
# ##Adding hues

# %%
sns.set_style("whitegrid")
plt.figure(figsize=(12,6))

plt.title("Sepal Dimension")

sns.scatterplot(x=flower_df.sepal_length, y=flower_df.sepal_width, hue=flower_df.species, s=100);

# %% [markdown]
# #Ploting using pandas dataframes

# %%
plt.figure(figsize=(12,6))
plt.title("Sepal Dimensions")

sns.scatterplot(x='sepal_length',
                y='sepal_width',
                hue='species',
                s=100,
                data=flower_df);

# %% [markdown]
# #Histogram
#
# A histogram represents the distribution of a variable by creating bins (interval) along the range of values and showing vertical bars to indicate the number of observations in each bin.
#
# `plt.hist`

# %%
flower_df.sepal_width
# Out:
# 0      3.5
# 1      3.0
# 2      3.2
# 3      3.1
# 4      3.6
#       ...
# 145    3.0
# 146    2.5
# 147    3.0
# 148    3.4
# 149    3.0
# Name: sepal_width, Length: 150, dtype: float64

# %%
plt.figure(figsize=(12,6))
plt.title("Distribution of Sepal Width")

plt.hist(flower_df.sepal_width);

# %%
#Specifying the number of bins
plt.hist(flower_df.sepal_width, bins=5); #Value of intervales

# %%
#Seting the boundarie of each bin
import numpy as np

plt.hist(flower_df.sepal_width, bins=np.arange(2, 5, 0.25));

# %% [markdown]
# ##Multiple histograms D:

# %%
setosa_df = flower_df[flower_df.species == 'setosa']
versicolor_df = flower_df[flower_df.species == 'versicolor']
virginica_df = flower_df[flower_df.species == 'virginica']

# %%
plt.figure(figsize=(12,6))
plt.hist(setosa_df.sepal_width, alpha=0.4, bins=np.arange(2,5,0.25));
plt.hist(versicolor_df.sepal_width, alpha=0.4, bins=np.arange(2,5,0.25));

# %%
#Stacking multiples histograms on top of each other

# %%
plt.title('Distribution of Sepal Width')


plt.hist([setosa_df.sepal_width, versicolor_df.sepal_width, virginica_df.sepal_width],
         bins=np.arange(2,5,0.25),
         stacked=True);

plt.legend(['Setosa', 'Versicolor', 'Virginica']);

# %% [markdown]
# #Bar chart

# %%
years = range(2000, 2006)
apples = [0.35, 0.6, 0.9, 0.8, 0.65, 0.8]
oranges = [0.4, 0.8, 0.9, 0.7, 0.6, 0.8]

# %%
plt.bar(years, apples);

# %%
plt.bar(years, oranges);

# %%
plt.figure(figsize=(12,6))
plt.bar(years, apples)
plt.bar(years, oranges, bottom=apples);

# %% [markdown]
# ##Bar plots with averages

# %%
tips_df = sns.load_dataset("tips");
tips_df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
plt.figure(figsize=(12,6))
sns.barplot(x='day',
            y= 'total_bill',
            data=tips_df);

# %%
# Adding sex to the plot:
plt.figure(figsize=(12,6))
sns.barplot(x='day',
            y= 'total_bill',
            hue='sex',
            data=tips_df);

# %%
#changing the axis
plt.figure(figsize=(12,6))
sns.barplot(x='total_bill',
            y= 'day',
            hue='sex',
            data=tips_df);

# %% [markdown]
# # Heatmap
#
# A heatmap is used to visualize 2-dimensional data like a matrix or a table using colors.

# %%
flights_df = sns.load_dataset("flights").pivot("month", "year", "passengers")
flights_df
# Out:
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472
# Jun     135   149   178   218   243   264   315   374   422   435   472   535
# Jul     148   170   199   230   264   302   364   413   465   491   548   622
# Aug     148   170   199   242   272   293   347   405   467   505   559   606
# Sep     136   158   184   209   237   259   312   355   404   404   463   508
# Oct     119   133   162   191   211   229   274   306   347   359   407   461
# Nov     104   114   146   172   180   203   237   271   305   310   362   390
# Dec     118   140   166   194   201   229   278   306   336   337   405   432

# %%
sns.heatmap(flights_df);

# %% [markdown]
# The brighter colors indicate a higher footfall at the airport. By looking at the graph, we can infer two things:
#
# - The footfall at the airport in any given year tends to be the highest around July & August.
# - The footfall at the airport in any given month tends to grow year by year.
#
# We can also display the actual values in each block by specifying `annot=True` and using the `cmap` argument to change the color palette.

# %%
plt.title("No. of passengers")

sns.heatmap(flights_df, fmt="d", annot=True, cmap='Blues');
